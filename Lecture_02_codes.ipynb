# %%
tuple=('jan', 'feb', 'march')
tuple
type(tuple)
a = input('Enter Roll No:')
print('Your Roll No is ' + a)
tuple = ("h", "b", "a", "c", "f", "d", "e", "g")
print(sorted(tuple))
print(sorted(tuple, reverse=True))
y=2,3,4,5,6,7
sum(y)
str(y)
max(y)
min(y)
len(y)
type(y)
round(y[1])
id(y)
pow(y[1],2)
z=[1,2,3,4,5,6,7]
x = -pow(3, 4)
print(x)
abs(x)

#statments
#if statement
marks=50
if marks>10:
    print("Student is Pass")
print("student is fail")
#If else Statement
##Example 1
marks=100
if marks>40:
    print("Student is pass")
else:
    print("Student is fail")
    #Nested If Else Statment
z=0
if z>0:
    if z%2==0:
        print("Z is positive even number")
    else:
        print("Z is positive odd number")
else:
    print("Z is positive odd number")
#if elif and else command
a=2;
b=3;
c=1;
if a>b and b>c:
        print("a is the largest number")
elif b>a and a>c:
        print("b is the largest number")
else:
    print("c is the largest number")
#Write your code to check when c=4; a=-1, b=-3
#You can use multiple if commands to check for different categories of number
d = range(5)
tt=0
for i in d:
    print(i)
else:print("no value left")
    
#Example file for working with loops
#
t=50
#define a while loop
while(t >10):
        print(t)
        t = t+1
##For Loop
for i in '12345':
 print ("stats123",i,)

#Example 2
var3=1,2,3
for i in range(len(var3)):
     print("The values is", var3[i])
